# %% [markdown]
# ## Pandas Built in data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("D:\\Study\\Python\\Repo\\DataScience\\Files\\df1",index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2  = pd.read_csv("D:\\Study\\Python\\Repo\\DataScience\\Files\\df2")

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
import seaborn as sns

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist',bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.5)

# %%
#bar plot
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=30)

# %%
#line
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-ff9f163dbf33> in <module>
#       1 #line
# ----> 2 df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
#
# D:\Study\Python\AnacondaInstall\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwds)
#    3003             >>> lines = df.plot.line(x='pig', y='horse')
#    3004         """
# -> 3005         return self(kind='line', x=x, y=y, **kwds)
#    3006
#    3007     def bar(self, x=None, y=None, **kwds):
#
# D:\Study\Python\AnacondaInstall\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
#scatter
df1.plot.scatter(x='A',y='B',color='C',cmap='coolwarm')
# Out:
# D:\Study\Python\AnacondaInstall\lib\site-packages\pandas\plotting\_core.py:211: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   warnings.warn("'color' and 'colormap' cannot be used "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-53dadf34fa13> in <module>
#       1 #scatter
# ----> 2 df1.plot.scatter(x='A',y='B',color='C',cmap='coolwarm')
#
# D:\Study\Python\AnacondaInstall\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ...

# %%
#or size
df1.plot.scatter(x='A',y='B',color='C',s=df1['C']*100)
# Out:
# D:\Study\Python\AnacondaInstall\lib\site-packages\matplotlib\collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#boxplot

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.178370  1.109563
# 1 -1.604742 -0.581353
# 2 -0.530151 -0.399747
# 3  0.675193 -0.924044
# 4 -0.462050  1.550891

# %%
df.plot.hexbin(x='a',y='b')

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')

# %%
#kde
df2['a'].plot.kde()

# %%
#or
df2['a'].plot.density()

# %%
#for all column
df2.plot.density()
